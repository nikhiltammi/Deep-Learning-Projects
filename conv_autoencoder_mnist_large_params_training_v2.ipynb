# %% [markdown]
# # Convolutional Autoencoder

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8

# %% [markdown]
# #### Import utility functions

# %%
from helper_data import get_dataloaders_mnist
from helper_train import train_autoencoder_v1
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_training_loss
from helper_plotting import plot_generated_images
from helper_plotting import plot_latent_space_with_labels

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 0
DEVICE = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', DEVICE)

# Hyperparameters
RANDOM_SEED = 123
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
NUM_EPOCHS = 20
# Out:
# Device: cuda:0

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## Dataset

# %%
##########################
### Dataset
##########################

train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    num_workers=2,
    validation_fraction=0.)

# %%
# Checking the dataset
print('Training Set:\n')
for images, labels in train_loader:
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    print(labels[:10])
    break

# Checking the dataset
print('\nValidation Set:')
for images, labels in valid_loader:
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    print(labels[:10])
    break

# Checking the dataset
print('\nTesting Set:')
for images, labels in test_loader:
    print('Image batch dimensions:', images.size())
    print('Image label dimensions:', labels.size())
    print(labels[:10])
    break
# Out:
# Training Set:
#
# Image batch dimensions: torch.Size([32, 1, 28, 28])
# Image label dimensions: torch.Size([32])
# tensor([1, 2, 1, 9, 0, 6, 9, 8, 0, 1])
#
# Validation Set:
#
# Testing Set:
# Image batch dimensions: torch.Size([32, 1, 28, 28])
# Image label dimensions: torch.Size([32])
# tensor([7, 2, 1, 0, 4, 1, 4, 9, 5, 9])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class Reshape(nn.Module):
    def __init__(self, *args):
        super().__init__()
        self.shape = args

    def forward(self, x):
        return x.view(self.shape)


class Trim(nn.Module):
    def __init__(self, *args):
        super().__init__()

    def forward(self, x):
        return x[:, :, :28, :28]


class AutoEncoder(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = nn.Sequential( #784
                nn.Conv2d(1, 32, stride=(1, 1), kernel_size=(3, 3), padding=1),
                nn.LeakyReLU(0.01),
                nn.Conv2d(32, 78, stride=(2, 2), kernel_size=(3, 3), padding=1),
                nn.LeakyReLU(0.01),
                nn.Conv2d(78, 78, stride=(2, 2), kernel_size=(3, 3), padding=1),
                nn.LeakyReLU(0.01),
                nn.Conv2d(78, 78, stride=(1, 1), kernel_size=(3, 3), padding=1),
                nn.Flatten(),
                nn.Linear(3822, 10)
        )
        self.decoder = nn.Sequential(
                torch.nn.Linear(10, 3822),
                Reshape(-1, 78, 7, 7),
                nn.ConvTranspose2d(78, 78, stride=(1, 1), kernel_size=(3, 3), padding=1),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose2d(78, 78, stride=(2, 2), kernel_size=(3, 3), padding=1),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose2d(78, 32, stride=(2, 2), kernel_size=(3, 3), padding=0),
                nn.LeakyReLU(0.01),
                nn.ConvTranspose2d(32, 1, stride=(1, 1), kernel_size=(3, 3), padding=0),
                Trim(),  # 1x29x29 -> 1x28x28
                nn.Sigmoid()
                )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
set_all_seeds(RANDOM_SEED)

model = AutoEncoder()
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ## Training

# %%
log_dict = train_autoencoder_v1(num_epochs=NUM_EPOCHS, model=model,
                                optimizer=optimizer, device=DEVICE,
                                train_loader=train_loader,
                                skip_epoch_stats=True,
                                logging_interval=250)
# Out:
# Epoch: 001/020 | Batch 0000/1875 | Loss: 0.2104
# Epoch: 001/020 | Batch 0250/1875 | Loss: 0.0392
# Epoch: 001/020 | Batch 0500/1875 | Loss: 0.0220
# Epoch: 001/020 | Batch 0750/1875 | Loss: 0.0180
# Epoch: 001/020 | Batch 1000/1875 | Loss: 0.0206
# Epoch: 001/020 | Batch 1250/1875 | Loss: 0.0185
# Epoch: 001/020 | Batch 1500/1875 | Loss: 0.0185
# Epoch: 001/020 | Batch 1750/1875 | Loss: 0.0139
# Time elapsed: 0.79 min
# Epoch: 002/020 | Batch 0000/1875 | Loss: 0.0157
# Epoch: 002/020 | Batch 0250/1875 | Loss: 0.0153
# Epoch: 002/020 | Batch 0500/1875 | Loss: 0.0162
# Epoch: 002/020 | Batch 0750/1875 | Loss: 0.0135
# Epoch: 002/020 | Batch 1000/1875 | Loss: 0.0151
# Epoch: 002/020 | Batch 1250/1875 | Loss: 0.0181
# Epoch: 002/020 | Batch 1500/1875 | Loss: 0.0146
# Epoch: 002/020 | Batch 1750/1875 | Loss: 0.0154
# Time elapsed: 1.53 min
# Epoch: 003/020 | Batch 0000/1875 | Loss: 0.0162
# Epoch: 003/020 | Batch 0250/1875 | Loss: 0.0148
# Epoch: 003/020 | Batch 0500/1875 | Loss: 0.0146
# Epoch: 003/020 | Batch 0750/1875 | Loss: 0.0165
# Epoch: 003/020 | Batch 1000/1875 | Loss: 0.0133
# Epoch: 003/020 | Batch 1250/1875 | Loss: 0.0115
# Epoch: 003/020 | Batch 1500/1875 | Loss: 0.0140
# Epoch: 003/020 | Batch 1750/1875 | Loss: 0.0127
# Time elapsed: 2.30 min
# Epoch: 004/020 | Batch 0000/1875 | Loss: 0.0148
# Epoch: 004/020 | Batch 0250/1875 | Loss: 0.0121
# Epoch: 004/020 | Batch 0500/1875 | Loss: 0.0124
# Epoch: 004/020 | Batch 0750/1875 | Loss: 0.0121
# Epoch: 004/020 | Batch 1000/1875 | Loss: 0.0116
# Epoch: 004/020 | Batch 1250/1875 | Loss: 0.0108
# Epoch: 004/020 | Batch 1500/1875 | Loss: 0.0140
# Epoch: 004/020 | Batch 1750/1875 | Loss: 0.0126
# Time elapsed: 3.04 min
# Epoch: 005/020 | Batch 0000/1875 | Loss: 0.0097
# Epoch: 005/020 | Batch 0250/1875 | Loss: 0.0147
# Epoch: 005/020 | Batch 0500/1875 | Loss: 0.0126
# Epoch: 005/020 | Batch 0750/1875 | Loss: 0.0129
# Epoch: 005/020 | Batch 1000/1875 | Loss: 0.0114
# Epoch: 005/020 | Batch 1250/1875 | Loss: 0.0140
# Epoch: 005/020 | Batch 1500/1875 | Loss: 0.0130
# Epoch: 005/020 | Batch 1750/1875 | Loss: 0.0108
# Time elapsed: 3.78 min
# Epoch: 006/020 | Batch 0000/1875 | Loss: 0.0111
# Epoch: 006/020 | Batch 0250/1875 | Loss: 0.0099
# Epoch: 006/020 | Batch 0500/1875 | Loss: 0.0156
# Epoch: 006/020 | Batch 0750/1875 | Loss: 0.0107
# Epoch: 006/020 | Batch 1000/1875 | Loss: 0.0107
# Epoch: 006/020 | Batch 1250/1875 | Loss: 0.0131
# Epoch: 006/020 | Batch 1500/1875 | Loss: 0.0111
# Epoch: 006/020 | Batch 1750/1875 | Loss: 0.0101
# Time elapsed: 4.51 min
# Epoch: 007/020 | Batch 0000/1875 | Loss: 0.0124
# Epoch: 007/020 | Batch 0250/1875 | Loss: 0.0116
# Epoch: 007/020 | Batch 0500/1875 | Loss: 0.0106
# Epoch: 007/020 | Batch 0750/1875 | Loss: 0.0107
# Epoch: 007/020 | Batch 1000/1875 | Loss: 0.0121
# Epoch: 007/020 | Batch 1250/1875 | Loss: 0.0116
# Epoch: 007/020 | Batch 1500/1875 | Loss: 0.0109
# Epoch: 007/020 | Batch 1750/1875 | Loss: 0.0107
# Time elapsed: 5.25 min
# Epoch: 008/020 | Batch 0000/1875 | Loss: 0.0094
# Epoch: 008/020 | Batch 0250/1875 | Loss: 0.0127
# Epoch: 008/020 | Batch 0500/1875 | Loss: 0.0118
# Epoch: 008/020 | Batch 0750/1875 | Loss: 0.0119
# Epoch: 008/020 | Batch 1000/1875 | Loss: 0.0106
# Epoch: 008/020 | Batch 1250/1875 | Loss: 0.0113
# Epoch: 008/020 | Batch 1500/1875 | Loss: 0.0103
# Epoch: 008/020 | Batch 1750/1875 | Loss: 0.0099
# Time elapsed: 5.99 min
# Epoch: 009/020 | Batch 0000/1875 | Loss: 0.0108
# Epoch: 009/020 | Batch 0250/1875 | Loss: 0.0093
# Epoch: 009/020 | Batch 0500/1875 | Loss: 0.0128
# Epoch: 009/020 | Batch 0750/1875 | Loss: 0.0121
# Epoch: 009/020 | Batch 1000/1875 | Loss: 0.0128
# Epoch: 009/020 | Batch 1250/1875 | Loss: 0.0119
# Epoch: 009/020 | Batch 1500/1875 | Loss: 0.0113
# Epoch: 009/020 | Batch 1750/1875 | Loss: 0.0120
# Time elapsed: 6.76 min
# Epoch: 010/020 | Batch 0000/1875 | Loss: 0.0117
# Epoch: 010/020 | Batch 0250/1875 | Loss: 0.0123
# Epoch: 010/020 | Batch 0500/1875 | Loss: 0.0109
# Epoch: 010/020 | Batch 0750/1875 | Loss: 0.0107
# Epoch: 010/020 | Batch 1000/1875 | Loss: 0.0114
# Epoch: 010/020 | Batch 1250/1875 | Loss: 0.0118
# Epoch: 010/020 | Batch 1500/1875 | Loss: 0.0114
# Epoch: 010/020 | Batch 1750/1875 | Loss: 0.0113
# Time elapsed: 7.49 min
# Epoch: 011/020 | Batch 0000/1875 | Loss: 0.0098
# Epoch: 011/020 | Batch 0250/1875 | Loss: 0.0126
# Epoch: 011/020 | Batch 0500/1875 | Loss: 0.0091
# Epoch: 011/020 | Batch 0750/1875 | Loss: 0.0120
# Epoch: 011/020 | Batch 1000/1875 | Loss: 0.0121
# Epoch: 011/020 | Batch 1250/1875 | Loss: 0.0136
# Epoch: 011/020 | Batch 1500/1875 | Loss: 0.0114
# Epoch: 011/020 | Batch 1750/1875 | Loss: 0.0125
# Time elapsed: 8.23 min
# Epoch: 012/020 | Batch 0000/1875 | Loss: 0.0104
# Epoch: 012/020 | Batch 0250/1875 | Loss: 0.0103
# Epoch: 012/020 | Batch 0500/1875 | Loss: 0.0119
# Epoch: 012/020 | Batch 0750/1875 | Loss: 0.0112
# Epoch: 012/020 | Batch 1000/1875 | Loss: 0.0112
# Epoch: 012/020 | Batch 1250/1875 | Loss: 0.0098
# Epoch: 012/020 | Batch 1500/1875 | Loss: 0.0125
# Epoch: 012/020 | Batch 1750/1875 | Loss: 0.0089
# Time elapsed: 8.97 min
# Epoch: 013/020 | Batch 0000/1875 | Loss: 0.0103
# Epoch: 013/020 | Batch 0250/1875 | Loss: 0.0133
# Epoch: 013/020 | Batch 0500/1875 | Loss: 0.0129
# Epoch: 013/020 | Batch 0750/1875 | Loss: 0.0100
# Epoch: 013/020 | Batch 1000/1875 | Loss: 0.0110
# Epoch: 013/020 | Batch 1250/1875 | Loss: 0.0091
# Epoch: 013/020 | Batch 1500/1875 | Loss: 0.0098
# Epoch: 013/020 | Batch 1750/1875 | Loss: 0.0089
# Time elapsed: 9.71 min
# Epoch: 014/020 | Batch 0000/1875 | Loss: 0.0102
# Epoch: 014/020 | Batch 0250/1875 | Loss: 0.0094
# Epoch: 014/020 | Batch 0500/1875 | Loss: 0.0110
# Epoch: 014/020 | Batch 0750/1875 | Loss: 0.0091
# Epoch: 014/020 | Batch 1000/1875 | Loss: 0.0103
# Epoch: 014/020 | Batch 1250/1875 | Loss: 0.0100
# Epoch: 014/020 | Batch 1500/1875 | Loss: 0.0107
# Epoch: 014/020 | Batch 1750/1875 | Loss: 0.0092
# Time elapsed: 10.44 min
# Epoch: 015/020 | Batch 0000/1875 | Loss: 0.0107
# Epoch: 015/020 | Batch 0250/1875 | Loss: 0.0110
# Epoch: 015/020 | Batch 0500/1875 | Loss: 0.0126
# Epoch: 015/020 | Batch 0750/1875 | Loss: 0.0141
# Epoch: 015/020 | Batch 1000/1875 | Loss: 0.0121
# Epoch: 015/020 | Batch 1250/1875 | Loss: 0.0110
# Epoch: 015/020 | Batch 1500/1875 | Loss: 0.0117
# Epoch: 015/020 | Batch 1750/1875 | Loss: 0.0099
# Time elapsed: 11.20 min
# Epoch: 016/020 | Batch 0000/1875 | Loss: 0.0094
# Epoch: 016/020 | Batch 0250/1875 | Loss: 0.0093
# Epoch: 016/020 | Batch 0500/1875 | Loss: 0.0103
# Epoch: 016/020 | Batch 0750/1875 | Loss: 0.0116
# Epoch: 016/020 | Batch 1000/1875 | Loss: 0.0106
# Epoch: 016/020 | Batch 1250/1875 | Loss: 0.0105
# Epoch: 016/020 | Batch 1500/1875 | Loss: 0.0108
# Epoch: 016/020 | Batch 1750/1875 | Loss: 0.0122
# Time elapsed: 11.94 min
# Epoch: 017/020 | Batch 0000/1875 | Loss: 0.0090
# Epoch: 017/020 | Batch 0250/1875 | Loss: 0.0095
# Epoch: 017/020 | Batch 0500/1875 | Loss: 0.0109
# Epoch: 017/020 | Batch 0750/1875 | Loss: 0.0108
# Epoch: 017/020 | Batch 1000/1875 | Loss: 0.0091
# Epoch: 017/020 | Batch 1250/1875 | Loss: 0.0100
# Epoch: 017/020 | Batch 1500/1875 | Loss: 0.0101
# Epoch: 017/020 | Batch 1750/1875 | Loss: 0.0098
# Time elapsed: 12.68 min
# Epoch: 018/020 | Batch 0000/1875 | Loss: 0.0118
# Epoch: 018/020 | Batch 0250/1875 | Loss: 0.0093
# Epoch: 018/020 | Batch 0500/1875 | Loss: 0.0087
# Epoch: 018/020 | Batch 0750/1875 | Loss: 0.0102
# Epoch: 018/020 | Batch 1000/1875 | Loss: 0.0110
# Epoch: 018/020 | Batch 1250/1875 | Loss: 0.0105
# Epoch: 018/020 | Batch 1500/1875 | Loss: 0.0090
# Epoch: 018/020 | Batch 1750/1875 | Loss: 0.0098
# Time elapsed: 13.42 min
# Epoch: 019/020 | Batch 0000/1875 | Loss: 0.0090
# Epoch: 019/020 | Batch 0250/1875 | Loss: 0.0082
# Epoch: 019/020 | Batch 0500/1875 | Loss: 0.0100
# Epoch: 019/020 | Batch 0750/1875 | Loss: 0.0094
# Epoch: 019/020 | Batch 1000/1875 | Loss: 0.0085
# Epoch: 019/020 | Batch 1250/1875 | Loss: 0.0085
# Epoch: 019/020 | Batch 1500/1875 | Loss: 0.0119
# Epoch: 019/020 | Batch 1750/1875 | Loss: 0.0118
# Time elapsed: 14.16 min
# Epoch: 020/020 | Batch 0000/1875 | Loss: 0.0099
# Epoch: 020/020 | Batch 0250/1875 | Loss: 0.0114
# Epoch: 020/020 | Batch 0500/1875 | Loss: 0.0096
# Epoch: 020/020 | Batch 0750/1875 | Loss: 0.0103
# Epoch: 020/020 | Batch 1000/1875 | Loss: 0.0091
# Epoch: 020/020 | Batch 1250/1875 | Loss: 0.0111
# Epoch: 020/020 | Batch 1500/1875 | Loss: 0.0114
# Epoch: 020/020 | Batch 1750/1875 | Loss: 0.0099
# Time elapsed: 14.89 min
# Total Training Time: 14.89 min

# %% [markdown]
# ## Evaluation

# %%
plot_training_loss(log_dict['train_loss_per_batch'], NUM_EPOCHS)
plt.show()

# %%
plot_generated_images(data_loader=train_loader, model=model, device=DEVICE)
